# %%
import os
os.environ["DATABASE_URL"] = "postgresql://complaint_routing_system_user:X8TPIBaBx3l8mnNGiATMsv7KYBNGjTjM@dpg-d71236vkijhs73ca0a10-a.virginia-postgres.render.com/complaint_routing_system"

# %%
import psycopg2

conn = psycopg2.connect(os.getenv("DATABASE_URL"))
print("Connected ✅")
# Out:
# Connected ✅

# %%
cur = conn.cursor()
cur.execute("SELECT user_id, name, role FROM users;")
users = cur.fetchall()
for user in users:
    print (user)
# Out:
# (1, 'Michael', 'customer')
# (3, 'Jawla', 'operator')
# (4, 'Lealem', 'customer')
# (5, 'Nebiyu', 'reviewer')

# %%
conn.rollback()
cur = conn.cursor()
cur.execute("SELECT complaint_id, predicted_department, predicted_priority, department_confidence_score, priority_confidence_score FROM complaints;")
complaints = cur.fetchall()
for complaint in complaints:
    print(complaint)
# Out:
# (1, 'Card services', 'Regular', 0.9554144166730297, 0.8912941511082754)
# (2, None, 'Regular', 0.32800428962076184, 0.8654694850359382)
